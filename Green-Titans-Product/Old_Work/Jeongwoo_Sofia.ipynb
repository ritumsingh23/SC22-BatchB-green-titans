# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib as mb
import matplotlib.pyplot as plt

# %%
crash2 = pd.read_csv('./train-new.csv')
crash2.keys()
# Out:
# Index(['dvcat', 'weight', 'dead', 'airbag', 'seatbelt', 'frontal', 'sex',
#        'ageOFocc', 'yearacc', 'yearVeh', 'abcat', 'occRole', 'deploy',
#        'caseid', 'injSeverity'],
#       dtype='object')

# %%
crash2.head()
# Out:
#    dvcat   weight   dead  airbag seatbelt  frontal sex  ageOFocc  yearacc  \
# 0    55+   53.342   dead  airbag   belted        1   f        48     2002
# 1  25-39  154.960  alive    none     none        1   m        26     2001
# 2    55+   38.994  alive    none     none        1   f        51     2002
# 3  25-39  168.568  alive  airbag   belted        1   m        27     1998
# 4  10-24   27.751  alive  airbag   belted        0   m        26     2002
#
#    yearVeh     abcat occRole  deploy    caseid  injSeverity
# 0     1997    deploy  driver       1  45:150:1            3
# 1     1968   unavail  driver       0   76:40:1            3
# 2     1994   unavail  driver       0  11:184:1            3
# 3     1996    deploy    pass       1    9:17:1            3
# 4     1997  nodeploy    pass       0     2:2:2            0

# %%
# injSeverityList = []
# inj0 = 0
# inj1 = 0
# inj2 = 0
# inj3 = 0
# inj4 = 0
# inj5 = 0
# for i in range (0, len(crash2)):
#     if(crash["injSeverity"][i]==0):
#         inj0+=1
#     elif(crash["injSeverity"][i]==1):
#         inj1+=1
#     elif(crash["injSeverity"][i]==2):
#         inj2+=1
#     elif(crash["injSeverity"][i]==3):
#         inj3+=1
#     elif(crash["injSeverity"][i]==4):
#         inj4+=1
#     else(crash["injSeverity"]][i]==5):
#         inj5+=1

grouped_df = crash2.groupby(["injSeverity"]).count()
grouped_df.head()
# Out:
#              dvcat  weight  dead  airbag  seatbelt  frontal   sex  ageOFocc  \
# injSeverity
# 0             4375    4375  4375    4375      4375     4375  4375      4375
# 1             3740    3740  3740    3740      3740     3740  3740      3740
# 2             2912    2912  2912    2912      2912     2912  2912      2912
# 3             5718    5718  5718    5718      5718     5718  5718      5718
# 4              729     729   729     729       729      729   729       729
#
#              yearacc  yearVeh  abcat  occRole  deploy  caseid
# injSeverity
# 0               4375     4375   4375     4375    4375    4375
# 1               3740     3740   3740     3740    3740    3740
# 2               2912     2912   2912     2912    2912    2912
# 3               5718     5718   5718     5718    5718    5718
# 4                729      729    729      729     729     729

# %%
crash2.loc[crash2['injSeverity'] > 3 & crash2["dead"]=="dead"] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     300         #  (xint or xbool) and (yint or bool)
# --> 301         result = op(x, y)
#     302     except TypeError:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/roperator.py in rand_(left, right)
#      51 def rand_(left, right):
# ---> 52     return operator.and_(right, left)
#      53
#
# TypeError: unsupported operand type(s) for &: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     314             try:
# --> 315                 result = libops.scalar_binop(x, y, op)
#     316             except (
#
# ...

# %%
# Out:
#        dvcat  weight   dead  airbag  seatbelt  frontal    sex  ageOFocc  \
# 0      False   False  False   False     False    False  False     False
# 1      False   False  False   False     False    False  False     False
# 2      False   False  False   False     False    False  False     False
# 3      False   False  False   False     False    False  False     False
# 4      False   False  False   False     False    False  False     False
# ...      ...     ...    ...     ...       ...      ...    ...       ...
# 17560  False   False  False   False     False    False  False     False
# 17561  False   False  False   False     False    False  False     False
# 17562  False   False  False   False     False    False  False     False
# 17563  False   False  False   False     False    False  False     False
# 17564  False   False  False   False     False    False  False     False
#
#        yearacc  yearVeh  abcat  occRole  deploy  caseid  injSeverity
# ...

# %%
p = 0
for i in range (0, len(crash2)):
   if(crash2["dead"][i]=="alive"):
        p+=1
print(p)
y = np.array([p, len(crash2) - p])
myLabels = ["alive", "dead"]
myColors = ["PaleGreen", "red"]
plt.pie(y, labels = myLabels, colors = myColors)
p/len(crash2)
# Out:
# 16788
# 0.9557643040136635
